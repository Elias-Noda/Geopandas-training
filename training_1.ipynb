# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
data = gpd.read_file('GeoData\\SP_Municipios_2022.shp')

# %%
data
# Out:
#       CD_MUN            NM_MUN SIGLA_UF  AREA_KM2  \
# 0    3500105        Adamantina       SP   411.987
# 1    3500204            Adolfo       SP   211.055
# 2    3500303             Aguaí       SP   474.554
# 3    3500402    Águas da Prata       SP   142.673
# 4    3500501  Águas de Lindóia       SP    60.126
# ..       ...               ...      ...       ...
# 640  3557006        Votorantim       SP   184.186
# 641  3557105       Votuporanga       SP   420.703
# 642  3557154          Zacarias       SP   319.056
# 643  3557204         Chavantes       SP   188.727
# 644  3557303      Estiva Gerbi       SP    74.144
#
#                                               geometry
# 0    POLYGON ((-51.09557 -21.57029, -51.09617 -21.5...
# 1    POLYGON ((-49.61249 -21.2611, -49.61249 -21.26...
# 2    POLYGON ((-47.01254 -22.00527, -47.01219 -22.0...
# 3    POLYGON ((-46.71875 -21.95837, -46.71878 -21.9...
# 4    POLYGON ((-46.61761 -22.51172, -46.61864 -22.5...
# ...

# %%
type(data)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
data.head(10)
# Out:
#     CD_MUN                  NM_MUN SIGLA_UF  AREA_KM2  \
# 0  3500105              Adamantina       SP   411.987
# 1  3500204                  Adolfo       SP   211.055
# 2  3500303                   Aguaí       SP   474.554
# 3  3500402          Águas da Prata       SP   142.673
# 4  3500501        Águas de Lindóia       SP    60.126
# 5  3500550  Águas de Santa Bárbara       SP   404.463
# 6  3500600      Águas de São Pedro       SP     3.612
# 7  3500709                  Agudos       SP   966.708
# 8  3500758                Alambari       SP   159.600
# 9  3500808       Alfredo Marcondes       SP   118.915
#
#                                             geometry
# 0  POLYGON ((-51.09557 -21.57029, -51.09617 -21.5...
# 1  POLYGON ((-49.61249 -21.2611, -49.61249 -21.26...
# 2  POLYGON ((-47.01254 -22.00527, -47.01219 -22.0...
# 3  POLYGON ((-46.71875 -21.95837, -46.71878 -21.9...
# 4  POLYGON ((-46.61761 -22.51172, -46.61864 -22.5...
# ...

# %%
data.tail(10)
# Out:
#       CD_MUN                NM_MUN SIGLA_UF  AREA_KM2  \
# 635  3556602             Vera Cruz       SP   247.716
# 636  3556701               Vinhedo       SP    80.950
# 637  3556800             Viradouro       SP   217.726
# 638  3556909  Vista Alegre do Alto       SP    95.429
# 639  3556958        Vitória Brasil       SP    49.832
# 640  3557006            Votorantim       SP   184.186
# 641  3557105           Votuporanga       SP   420.703
# 642  3557154              Zacarias       SP   319.056
# 643  3557204             Chavantes       SP   188.727
# 644  3557303          Estiva Gerbi       SP    74.144
#
#                                               geometry
# 635  POLYGON ((-49.7961 -22.17718, -49.79612 -22.17...
# 636  POLYGON ((-46.98432 -23.08088, -46.98436 -23.0...
# 637  POLYGON ((-48.29477 -20.83283, -48.29472 -20.8...
# 638  POLYGON ((-48.61715 -21.20002, -48.61776 -21.1...
# 639  POLYGON ((-50.45066 -20.15889, -50.45186 -20.1...
# ...

# %%
data.plot()
# Out:
# <Axes: >

# %%
data.plot(figsize=(16,14),
        facecolor='white',
        edgecolor='black')
plt.show()

# %%
gdf_sp = data[data['NM_MUN'] == 'São Paulo']
gdf_sp
# Out:
#       CD_MUN     NM_MUN SIGLA_UF  AREA_KM2  \
# 562  3550308  São Paulo       SP  1521.202
#
#                                               geometry
# 562  POLYGON ((-46.63512 -23.8385, -46.63455 -23.84...

# %%
gdf_sp.plot(figsize=(8,8),
        facecolor='white',
        edgecolor='black')
plt.show()

# %%
filename = 'data/capital_são_paulo.json'
gdf_sp.to_file(filename, driver="GeoJSON")

# %%
gdf_sp = gpd.read_file(filename, driver="GeoJSON")
gdf_sp
# Out:
# c:\Users\Rion\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyogrio\raw.py:196: RuntimeWarning: driver GeoJSON does not support open option DRIVER
#   return ogr_read(
#     CD_MUN     NM_MUN SIGLA_UF  AREA_KM2  \
# 0  3550308  São Paulo       SP  1521.202
#
#                                             geometry
# 0  POLYGON ((-46.63512 -23.8385, -46.63455 -23.84...
